# %% [markdown]
# # LAB 1: Gradient Descent and Stuff
# ### AI and Machine Learning // Suchkova Natalia М8О - 114М - 22
# 30.09.2022 @ MAI IT-Center

# %% [markdown]
# <a id='g66'></a>

# %% [markdown]
# ## Table of Contents

# %% [markdown]
# 1. [**Chosen Functions' Formulas**](#g5)
#
#
# 2. [**Functions' Visualization**](#g4)
#
#     -[Himmelblau Function](#g4)
#
#     -[Rastrigin Function](#g3)
#
#     -[Rosenbrock Function](#g2)
#
#
# 3. [**Classical Gradient Descent**](#g1)
#
#     -[For Himmelblau](#g6)
#
#     -[For Rastrigin](#g7)
#
#     -[For Rosenbrock](#g8)
#
#
# 4. [**Сlassical Stochastic Gradient Descent**](#g9)
#
#     -[Loss Function & Data Generation](#g10)
#
#     -[SGD Method Code](#g11)
#
#
# 5. [**SGD with lr_scheduler**](#g12)
#
#
# 6. [**Momentum**](#g13)
#
#
# 7. [**Adaptive**](#g14)

# %%
import numpy as np
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
from typing import Tuple, Mapping
from sklearn.datasets import make_blobs

from matplotlib import cm 
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# <a id='g5'></a>

# %% [markdown]
# ## Real Functions Formulas & Visualization

# %% [markdown]
# **Функция Химмельблау**	$f(x,y) = (x^2 + y - 11)^2 + (x + y^2 - 7)^2 $ - попроще
#
# **Функция Розенброка**	$f(x) = \displaystyle\sum_{i=1}^{n-1} \big\lbrack 100(x_{i+1} - x_i^2)^2 +(x_i - 1)^2 \big\rbrack$  - посложнее
#
# **Функция Растригина** $f(x) = An + \displaystyle\sum_{i=1}^{n} \big\lbrack  x_i^2 - Acos(2pix_i) \big\rbrack$, where $A = 10$

# %%
class Himmelblau:
    
    def function(x: np.ndarray) -> np.float64:
        return (x[0]**2 + x[1] - 11)**2 + (x[0] + x[1]**2 - 7)**2
    
    def gradient(x: np.ndarray) -> np.array:
        return np.array([4 * x[0] * (x[0]**2 + x[1] - 11) \
                         + 2 * (x[0] + x[1]**2 - 7),
                         2 * (x[0]**2 + x[1] - 11) \
                         + 4 * x[1] * (x[0] + x[1]**2 - 7)])

class Rosenbrock: 
    
    def function(x: np.ndarray, b: int = 100) -> np.float64:
        return b * (x[1] - x[0]**2)**2 + (x[0] - 1)**2

    def gradient(x: np.ndarray, b: int = 100) -> np.array:

        return np.array([2 * (x[0] - 1) - 4 * b * x[0] * (x[1] - x[0]**2),
                         2 * b * (x[1] - x[0]**2)])
    
class Rastrigin:
    
    def function(x: np.float32, A: int = 10) -> np.float64:
        return x**2 - A * np.cos(2 * np.pi * x) # + A
    
    def gradient(x: np.float32, A: int = 10) -> np.float64:
            return 2 * x + A * 2 * np.pi * np.sin(2 * np.pi * x)

# %%
# class Himmelblau:
    
#     def function (x: np.float32, y: np.float32) -> np.float64:
#         return (x**2 + y - 11)**2 + (x + y**2 - 7)**2
    
#     def gradient (x: np.ndarray) -> np.array:
        
#         try:  # for both cases where start is a dot and a batch as in sgd
#             grads = []
#             for dot in x:
#                 grad_x = 4 * dot[0] * (dot[0]**2 + dot[1] - 11) + \
#                         2 * (dot[0] + dot[1]**2 - 7)
#                 grad_y = 2 * (dot[0]**2 + dot[1] - 11) + \
#                           4 * dot[1] * (dot[0] + dot[1]**2 - 7)
#                 grads.append([grad_x, grad_y])
#             grads_array = np.array(grads, dtype=float)
#             # mean as statistic mean (sum of vectors value at dot = mean of values of vectors)
#             return np.array([grads_array.T[0].mean(), grads_array.T[1].mean()])

            
#         except IndexError:
#             grad_x = 4 * x[0] * (x[0]**2 + x[1] - 11) + \
#                             2 * (x[0] + x[1]**2 - 7)
#             grad_y = 2 * (x[0]**2 + x[1] - 11) + \
#                       4 * x[1] * (x[0] + x[1]**2 - 7)
#             return np.array([grad_x, grad_y])



# class Rosenbrock: 
    
#     def function(x0: np.float32, x1: np.float32, b: int = 100) -> np.float64:
#         return b * (x1 - x0**2)**2 + (x0 - 1)**2

#     def gradient(x: np.ndarray, b: int = 100) -> np.array:

#         try:  # for both cases where start is a dot and a batch as in sgd
#             grads = []
#             for dot in x:
#                # print(dot)
#                 grad_x0 = 2 * (dot[0] - 1) - 4 * b * dot[0] * (dot[1] - dot[0]**2)
#                 grad_x1 = 2 * b * (dot[1] - dot[0]**2)
#                 grads.append([grad_x0, grad_x1])
#             grads_array = np.array(grads, dtype=float)
#            # grads = np.array([grad_x0, grad_x1])
#             return np.array([grads_array.T[0].mean(), grads_array.T[1].mean()])
            
#         except IndexError:
#             grad_x0 = 2 * (x[0] - 1) - 4 * b * x[0] * (x[1] - x[0]**2)
#             grad_x1 = 2 * b * (x[1] - x[0]**2)
#             return np.array([grad_x0, grad_x1])
        
#     def gradient2(x: np.ndarray, b: int = 100) -> np.array:
#         grad_x0 = 2 * (x[0] - 1) - 4 * b * x[0] * (x[1] - x[0]**2)
#         grad_x1 = 2 * b * (x[1] - x[0]**2)
#         return np.array([grad_x0, grad_x1])

# # def rosenbrock_derivative(x):
# #     xm = x [1: -1]
# #     xm_m1 = x [: - 2]
# #     xm_p1 = x [2:]
# #     der = np.zeros_like (x)
# #     der [1: -1] = 200 * (xm-xm_m1 ** 2) - 400 * (xm_p1 - xm ** 2) * xm - 2 * (1-xm)
# #     der [0] = -400 * x [0] * (x [1] -x [0] ** 2) - 2 * (1-x [0])
# #     der [-1] = 200 * (x [-1] -x [-2] ** 2)
# #     return der
    
# class Rastrigin:
    
#     def function (x: np.float32, A: int = 10) -> np.float64:
#         return x**2 - A * np.cos(2 * np.pi * x) # + A
    
#     def gradient (x: np.float32, A: int = 10) -> np.float64:
#             return 2 * x + A * 2 * np.pi * np.sin(2 * np.pi * x)


# #def Rastrigin (X: np.float32, A: int = 10) -> np.float64:
#  #   delta = [x**2 - A * np.cos(2 * np.pi * x) for x in X]
#   #  return A + np.sum(delta)

# # def rastriginPy(X):
# #     A = 10.0
# #     delta = [x**2 - A * np.cos(2 * np.pi * x) for x in X]
# #     y = A + sum(delta)
# #     return [y]

# def test_grad(x: np.ndarray) -> np.float64:

#         try:  # for both cases where start is a dot and a batch as in sgd
#             grads = []
#             for dot in x:
#                # print(dot)
#                 grad_x0 = 2 * x[0]
#                 grad_x1 = 2 * x[1]
#                 grads.append([grad_x0, grad_x1])
#             grads_array = np.array(grads, dtype=float)
#            # grads = np.array([grad_x0, grad_x1])
#             return np.array([grads_array.T[0].mean(), (grads_array.T[1]).mean()])
            
#         except IndexError:
#             return 2 * x

# %% [markdown]
# <a id='g4'></a>

# %% [markdown]
# # Visualize

# %% [markdown]
# ## Himmelblau Function

# %%
X = np.linspace(-5.12, 5.12, 100)
Y = np.linspace(-5.12, 5.12, 100)
X, Y = np.meshgrid(X, Y) 

Z = Himmelblau.function(X, Y)

figRos = plt.figure(figsize=(12, 7))
axRos = plt.axes(projection='3d')
axRos.view_init(elev=30., azim=-19)

surf = axRos.plot_surface(X, Y, Z, cmap=cm.gist_heat_r,
                       linewidth=0, antialiased=False)
axRos.set_zlim(0, 800)
figRos.colorbar(surf, shrink=0.5, aspect=10)
plt.show()

# %% [markdown]
# <a id='g3'></a>

# %% [markdown]
# ## Rastrigin Function

# %%
X = np.linspace(-5.12, 5.12, 100)     
Y = np.linspace(-5.12, 5.12, 100)     
X, Y = np.meshgrid(X, Y) 

Z = (X**2 - 10 * np.cos(2 * np.pi * X)) + \
  (Y**2 - 10 * np.cos(2 * np.pi * Y))

fig = plt.figure(figsize=(12,8)) 
ax = plt.axes(projection='3d')
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
  cmap=cm.nipy_spectral, linewidth=0.08,
  antialiased=True)    
ax.set_zlim(0, 65)
# plt.savefig('rastrigin_graph.png')
plt.show()

# %% [markdown]
# <a id='g2'></a>

# %% [markdown]
# ## Rosenbrock Function

# %%
X = np.arange(-2, 2, 0.15)
Y = np.arange(-1, 3, 0.15)
X, Y = np.meshgrid(X, Y)

Z = Rosenbrock.function(X, Y)

fig = plt.figure(figsize=(12,8)) 
ax = plt.axes(projection='3d') 
ax.plot_surface(X, Y, Z, rstride=1, cstride=1,
                cmap=cm.nipy_spectral, linewidth=0.08,
                antialiased=True)    
ax.set_zlim(0, 2000)
# plt.savefig('rosenbrock_graph.png')
plt.show()

# %% [markdown]
# <a id='g1'></a>

# %% [markdown]
# ## My Classic Gradient Descent Function

# %%
def classic_GD (function: Mapping, gradient_of_function: Mapping,
                start: np.ndarray, x_data = False, y_labels = False, 
                learning_rate: float = 0.01, n_iter: int = 100, 
                tolerance: float = 1e-5) -> Tuple [np.ndarray, np.float32]:
    
    """ I' ll put here documentation later
    а еще я сделаю хотя бы одну визуализацию динамики loss для сгд
    сделаю визуализацию движения точки при поиске минимума
    может быть: могу добавить датасет, который будет собирать все показания и при каждом запуске 
    того или иного метода""" 
    
    if n_iter <= 0 or learning_rate <= 0:
        raise ValueError("'n_iter' and 'learning_rate' must be greater than zero")
        
    current_point = start.copy()
    current_point = current_point.astype('float64')
    
    for iter in range(n_iter):
        if type(x_data) == bool:
            diff = learning_rate * -gradient_of_function(current_point)
            if np.all(np.abs(diff) <= tolerance):
                break
            current_point += learning_rate * -gradient_of_function(current_point)
            
        else:
            current_point -= learning_rate * gradient_of_function(current_point, x_data, y_labels)
        
    return f'Minimum point coordinates {current_point},\
    with function value = {round(function(current_point), 4)}' if type(x_data) == bool else \
    f'Minimum point coordinates {current_point},\
    with function value = {function(current_point, x_data, y_labels)}'

# %% [markdown]
# Тест: Функция сферы $f(x) = \displaystyle\sum_{i=1}^{n} x_i^2$

# %%
def test_funk_1(x: np.ndarray) -> np.float64:
    return np.sum(np.square(x))

def test_f1_grad(x: np.ndarray) -> np.float64:
    return 2 * x

# %%
test_funk_1(np.array([2,2]))
# Out:
# 8

# %%
test_f1_grad(np.array([2,2]))
# Out:
# array([4, 4])

# %%
classic_GD(test_funk_1, test_f1_grad, np.array([100, 100]), learning_rate=0.001, n_iter=4500)
# Out:
# 'Minimum point coordinates [0.01223026 0.01223026],    with function value = 0.0003'

# %% [markdown]
# <a id='g6'></a>

# %% [markdown]
# ### Himmelblau

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://wikimedia.org/api/rest_v1/media/math/render/svg/3b6d888196974f862467cfe02748f3ae2ffdf476")
# Out:
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/3b6d888196974f862467cfe02748f3ae2ffdf476"/>

# %%
classic_GD(Himmelblau.function, Himmelblau.gradient, np.array([-100, -100]), learning_rate=0.00001, n_iter=9500)
# Out:
# 'Minimum point coordinates [-3.78824381 -3.29729647],    with function value = 0.0099'

# %% [markdown]
# Видим, что на функции Химмельблау обычный градиентный спуск вполне себе хорошо справляется с задачей минимизации.

# %% [markdown]
# <a id='g7'></a>

# %% [markdown]
# ### Rastrigin

# %%
Image(url= "https://wikimedia.org/api/rest_v1/media/math/render/svg/0ef36b9a7230888e739f302e1a5d67e36c152de8")
# Out:
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/0ef36b9a7230888e739f302e1a5d67e36c152de8"/>

# %%
# %%time
classic_GD(Rastrigin.function, Rastrigin.gradient, np.array([100, 100]), learning_rate=0.1, n_iter=1000)
# Out:
# Wall time: 25.4 ms
# 'Minimum point coordinates [8.99082509 8.99082509],    with function value = 71.859'

# %% [markdown]
# Работает, но хуже.

# %% [markdown]
# <a id='g8'></a>

# %% [markdown]
# ### Rosenbrock

# %%
Image(url= "https://wikimedia.org/api/rest_v1/media/math/render/svg/53f008f82897059e3591d0a9a0aa27b60a1745b4")
# Out:
# <img src="https://wikimedia.org/api/rest_v1/media/math/render/svg/53f008f82897059e3591d0a9a0aa27b60a1745b4"/>

# %%
Rosenbrock.gradient(np.array([2,2]))
# Out:
# array([1602, -400])

# %%
# %%time
classic_GD(Rosenbrock.function, Rosenbrock.gradient, np.array([10, 10]), learning_rate=0.00001, n_iter=1000)
# Out:
# Wall time: 13 ms
# 'Minimum point coordinates [ 3.2404417  10.50383904],    with function value = 5.0207'

# %% [markdown]
# С Розенброком ему тоже сложно. Не отлично, но и не ужасно, кстати, для самого простого метода.

# %% [markdown]
# <a id='g9'></a>

# %% [markdown]
# ## Stochastic Gradient Descent

# %% [markdown]
# <a id='g10'></a>

# %% [markdown]
# Выберу MSE как функцию потерь.

# %%
def MSE_loss(opt: np.ndarray, x: np.ndarray, y: np.ndarray) -> np.float64:
    loss = np.zeros(opt.shape, dtype = np.float64)
    for i in range(len(x)):
        loss[y[i]] += (x[i] - opt[y[i]])**2
    return loss / len(x)

def loss_grad(opt: np.ndarray, x: np.ndarray, y: np.ndarray) -> np.float64:
    loss = np.zeros(opt.shape, dtype = np.float64)
    for i in range(len(x)):
        loss[y[i]] += 2 * (x[i] - opt[y[i]])
    return loss / len(x)

# %% [markdown]
# Генерим данные.

# %%
X, y = make_blobs(n_samples=1000, centers= [[3, 1], [-2, -5]], n_features=2,
                  random_state=12)
print(X.shape)
print(len(X), len(y))

start_point = np.array([[5, 1], [-4, 13]])
# Out:
# (1000, 2)
# 1000 1000

# %%
x_plot = X.T
x_plot
# Out:
# array([[-2.29331445, -1.626728  , -2.22576635, ..., -3.09506781,
#          3.18861018, -1.28397647],
#        [-3.3463876 , -4.80824985, -4.80718951, ..., -6.38711036,
#          1.8568406 , -4.52922717]])

# %%
plt.scatter(x_plot[0], x_plot[1], c='pink')
plt.show()

# %%
# %%time
classic_GD(MSE_loss, loss_grad, start_point, x_data=X, y_labels=y, learning_rate=0.1, n_iter=4500)
# Out:
# Wall time: 53.7 s
# 'Minimum point coordinates [[ 3.70119406e+186  4.10379706e+184]\n [-3.56868538e+186  3.33796210e+187]],    with function value = [[inf inf]\n [inf inf]]'

# %% [markdown]
# Классический градиентный спуск вообще плохо работает на таких данных. И очень медленно.

# %% [markdown]
# <a id='g11'></a>

# %%
def SGD(
        function: Mapping, gradient: Mapping, start: np.ndarray,
        x = False, y = False,
        n_iter: int = 100, learning_rate: float = 0.01, 
        batch_size: int = 10, tolerance=1e-06, 
        dtype="float64", rand_state: int = 12
        ) -> Tuple [np.ndarray, np.ndarray]:
 
    dtype_ = np.dtype(dtype)
    
    if n_iter <= 0 or learning_rate <= 0:
        raise ValueError("'n_iter' and learning rate \
                         must be greater than zero")
   
#     idx = 0
#     while idx < len(x):
#         new = function(x[idx][0], x[idx][1])
#         x[idx][1] = new
#         idx += 1
    
#     for dot in x: # don't need this one
#         y = function(dot[0], dot[1])
        
    cur_point = start.copy()
    cur_point = cur_point.astype('float64')
    
    rng = np.random.default_rng(seed=rand_state)
    
    if type(x) != bool:
        n_obs = x.shape[0]
        if n_obs != y.shape[0]:
            raise ValueError("'x' and 'y' lengths do not match")
        
        xy = np.c_[x.reshape(n_obs, -1), y.T]

    for _ in range(n_iter): # gradient descent loop
        diff = np.zeros(cur_point.shape, dtype=dtype_)
        
        if type(x) != bool:
            rng.shuffle(xy)
            
            if not 0 < batch_size <= n_obs:
                raise ValueError( "'batch_size' must be > 0 and <= \
                                    than the number of observations")
                    
            for start in range(0, n_obs, batch_size): # batch moves
                stop = start + batch_size
                y_cut = xy[start:stop, -1:].astype('int')
                diff -= learning_rate * -gradient(cur_point, xy[start:stop, :-1], y_cut)

                if np.all(np.abs(diff) <= tolerance):
                    break
                cur_point += diff
           # print(cur_point)
        else:
            diff = learning_rate * -gradient(cur_point)
            if np.all(np.abs(diff) <= tolerance):
                break
            cur_point += diff
                
    return [cur_point, function(cur_point, x, y)] if type(x) != bool else [cur_point, function(cur_point)]

# %%
# import warnings
# warnings.filterwarnings('ignore')

# %%
SGD(test_funk_1, test_f1_grad, np.array([100, 100]),
        x = False, y = False,
        n_iter=440, learning_rate=0.01)
# Out:
# [array([0.01378711, 0.01378711]), 0.0003801689165099048]

# %%
# %%time
SGD(test_funk_1, test_f1_grad, np.array([100, 100]), learning_rate=0.01, n_iter=300)
# Out:
# Wall time: 3.99 ms
# [array([0.23325057, 0.23325057]), 0.10881165382051067]

# %%
# %%time
SGD(Rosenbrock.function, Rosenbrock.gradient, np.array([10, 100]), learning_rate=0.0001, n_iter=10)
# Out:
# Wall time: 0 ns
# [array([8.96569399e+47, 1.58993466e+31]), 6.461534197557863e+193]

# %%
# %%time
SGD(MSE_loss, loss_grad, start_point, x=X, y=y,
        n_iter=50, learning_rate=0.01, 
        batch_size=60)
# Out:
# Wall time: 1.82 s
# [array([[ 2.98636359,  0.99695545],
#         [-2.08268874, -5.05652054]]),
#  array([[0.53981367, 0.51332283],
#         [0.47080766, 0.46542449]])]

# %% [markdown]
# Работает хорошо и быстро.

# %% [markdown]
# <a id='g12'></a>

# %% [markdown]
# ## SGD with lr_scheduler

# %%
def SGD_sched(
        function: Mapping, gradient: Mapping, start: np.ndarray,
        x = False, y = False, schedule_lr: np.float64 = 0.6,
        n_iter: int = 100, learning_rate: float = 0.01, 
        batch_size: int = 10, tolerance=1e-06, 
        dtype="float64", rand_state: int = 12
        ) -> Tuple [np.ndarray, np.ndarray]:
 
    dtype_ = np.dtype(dtype)
    
    if n_iter <= 0 or learning_rate <= 0:
        raise ValueError("'n_iter' and learning rate \
                         must be greater than zero")

        
    cur_point = start.copy()
    cur_point = cur_point.astype('float64')
    
    rng = np.random.default_rng(seed=rand_state)

    if type(x) != bool:
        n_obs = x.shape[0]
        if n_obs != y.shape[0]:
            raise ValueError("'x' and 'y' lengths do not match")
        
        xy = np.c_[x.reshape(n_obs, -1), y.T]

        x = x.reshape(n_obs, -1)
        y = y.T

    for _ in range(n_iter): # gradient descent loop
        diff = np.zeros(cur_point.shape, dtype=dtype_)
        
        if type(x) != bool:
            rng.shuffle(xy)
            
            if not 0 < batch_size <= n_obs:
                raise ValueError( "'batch_size' must be > 0 and <= \
                                    than the number of observations")
                    
            for start in range(0, n_obs, batch_size): # batch moves
                stop = start + batch_size
                y_cut = xy[start:stop, -1:].astype('int')
                if _ <= 1: #from second iteration we start to slow down
                    diff -= learning_rate * -gradient(cur_point, xy[start:stop, :-1], y_cut)
                else:
                    diff -= learning_rate * schedule_lr * -gradient(cur_point, xy[start:stop, :-1], y_cut)

                if np.all(np.abs(diff) <= tolerance):
                    break
                    
                cur_point += diff
        
        else:
            if _ < 1:
                diff = learning_rate * -gradient(cur_point)
            else:
                diff = learning_rate * schedule_lr * -gradient(cur_point)
            if np.all(np.abs(diff) <= tolerance):
                break
                
            cur_point += diff
                
    return [cur_point, function(cur_point, x, y)] if type(x) != bool else [cur_point, function(cur_point)]

# %%
SGD_sched(test_funk_1, test_f1_grad, np.array([100, 100]),
        x = False, y = False,
        n_iter=70, learning_rate=0.1)
# Out:
# [array([0.01181393, 0.01181393]), 0.00027913784823732944]

# %%
# %%time
SGD_sched(MSE_loss, loss_grad, start_point, x=X, y=y,
        n_iter=50, learning_rate=0.01, 
        batch_size=60)
# Out:
# Wall time: 1.99 s
# [array([[ 2.99099095,  0.99930063],
#         [-2.07358328, -5.05281491]]),
#  array([[0.53976615, 0.51337047],
#         [0.47073893, 0.46539502]])]

# %% [markdown]
# Работают с примерно одинаковой скоростью, иногда scheduler ускоряет работу. Но во-первых, сгд и сгд с щедюлером нужно намного меньше итераций, чтобы найти минимум, во-вторых сгд с щедьюлером дает чуть более точные результаты.

# %% [markdown]
# <a id='g13'></a>

# %% [markdown]
# ## Momentum Method
# sgd with momentum

# %%
def SGD_momentum(
                function: Mapping, gradient: Mapping, start: np.ndarray,
                x = False, y = False, momentum: np.float64 = 0.1,
                n_iter: int = 100, learning_rate: float = 0.01, 
                batch_size: int = 10, tolerance=1e-06, 
                dtype="float64", rand_state: int = 12
            ) -> Tuple [np.ndarray, np.ndarray]:
 
    dtype_ = np.dtype(dtype)
    
    if n_iter <= 0 or learning_rate <= 0:
        raise ValueError("'n_iter' and learning rate \
                         must be greater than zero")
        
    cur_point = start.copy()
    cur_point = cur_point.astype('float64')
    
    rng = np.random.default_rng(seed=rand_state)

    if type(x) != bool:
        n_obs = x.shape[0]
        
        if n_obs != y.shape[0]:
            raise ValueError("'x' and 'y' lengths do not match")
            
        xy = np.c_[x.reshape(n_obs, -1), y.T]
    
    diff_cum = np.zeros(cur_point.shape, dtype=dtype_)  # cumulative to use previous difference

    for _ in range(n_iter): # gradient descent loop
        diff = np.zeros(cur_point.shape, dtype=dtype_)
        
        if type(x) != bool:
            rng.shuffle(xy)
            
            if not 0 < batch_size <= n_obs:
                raise ValueError( "'batch_size' must be > 0 and <= \
                                    than the number of observations")
                    
            for start in range(0, n_obs, batch_size): # batch moves
                stop = start + batch_size
                y_cut = xy[start:stop, -1:].astype('int')
                diff -= learning_rate * -gradient(cur_point, xy[start:stop, :-1], y_cut)
                diff_cum = momentum * diff_cum - diff

                if np.all(np.abs(diff) <= tolerance):
                    break
                    
                cur_point -= diff_cum
        
        else:
            diff = learning_rate * -gradient(cur_point)
            diff_cum = momentum * diff_cum - diff
            
            if np.all(np.abs(diff) <= tolerance):
                break
                
            cur_point -= diff_cum
                
    return [cur_point, function(cur_point, x, y)] if type(x) != bool else [cur_point, function(cur_point)]

# %%
SGD_momentum(test_funk_1, test_f1_grad, np.array([100, 100]),
        x = False, y = False, momentum=0.5,
        n_iter=1000, learning_rate=0.001)
# Out:
# [array([1.79492292, 1.79492292]), 6.443496586456419]

# %%
# %%time
SGD_momentum(MSE_loss, loss_grad, np.array([[5, 1], [-4, 13]]), x=X, y=y,
        n_iter=100, learning_rate=0.01, momentum=0.4,
        batch_size=80)
# Out:
# Wall time: 3.94 s
# [array([[ 2.97680511,  0.98141789],
#         [-2.04509874, -5.06807872]]),
#  array([[0.53997963, 0.5131461 ],
#         [0.47105929, 0.46560461]])]

# %% [markdown]
# По времени не ускоряет, работает даже чуть медленнее, чем обычный сгд и требует настройки гиперпараметров - без подбора дает результаты хуже обычного сгд. Больше батч - лучше, меньше моментум - тожу лучше, значит он нам мешает. Много итераций не нужно.

# %% [markdown]
# <a id='g14'></a>

# %% [markdown]
# ## Adam (Adaptive)

# %%
def GD_Adam(
            function: Mapping, gradient: Mapping, start: np.ndarray,
            x = False, y = False, momentum: np.float64 = 0.1,
            n_iter: int = 100, learning_rate: float = 0.01, 
            batch_size: int = 10, tolerance=1e-06, 
            dtype="float64", rand_state: int = 12
            ) -> Tuple [np.ndarray, np.ndarray]:
 
    dtype_ = np.dtype(dtype)
    
    if n_iter <= 0 or learning_rate <= 0:
        raise ValueError("'n_iter' and learning rate \
                         must be greater than zero")
        
    cur_point = start.copy()
    cur_point = cur_point.astype('float64')
    
    rng = np.random.default_rng(seed=rand_state)

    if type(x) != bool:
        n_obs = x.shape[0]
        
        if n_obs != y.shape[0]:
            raise ValueError("'x' and 'y' lengths do not match")
            
        xy = np.c_[x.reshape(n_obs, -1), y.T]
    
    diff_cum = np.zeros(cur_point.shape, dtype=dtype_)  # cumulative to use previous difference

    for _ in range(n_iter): # gradient descent loop
        diff = np.zeros(cur_point.shape, dtype=dtype_)
        
        if type(x) != bool:
            rng.shuffle(xy)
            
            if not 0 < batch_size <= n_obs:
                raise ValueError( "'batch_size' must be > 0 and <= \
                                    than the number of observations")
                    
            for start in range(0, n_obs, batch_size): # batch moves
                stop = start + batch_size
                y_cut = xy[start:stop, -1:].astype('int')
                diff -= learning_rate * -gradient(cur_point, xy[start:stop, :-1], y_cut)
                diff_cum = momentum * diff_cum - diff

                if np.all(np.abs(diff) <= tolerance):
                    break
                    
                cur_point -= diff_cum
        
        else:
            diff = learning_rate * -gradient(cur_point)
            diff_cum = momentum * diff_cum - diff
            
            if np.all(np.abs(diff) <= tolerance):
                break
                
            cur_point -= diff_cum
                
    return [cur_point, function(cur_point, x, y)] if type(x) != bool else [cur_point, function(cur_point)]

# %%
from ipywidgets import interactive

def f(x1, x2): return 100*(x2-x1**2)**2+(x1-1)**2
x1 = np.linspace(-5, 10)
x2 = np.linspace(-5, 10)
X1, X2 = np.meshgrid(x1, x2)
F = Himmelblau.function(x1, x2)
plt.contour(X1, X2, f(X1, X2))

def plotter(E, A):
  fig = plt.figure(figsize = [12, 8])
  ax = plt.axes(projection='3d')
  ax.plot_surface(X1, X2, Himmelblau.function(X1, X2), cmap='jet', alpha=0.8)
  ax.plot_wireframe(X1, X2, Himmelblau.function(X1, X2), rcount=15, ccount=15)
  ax.view_init(elev=E, azim=A)
  ax.set_xlabel('X')
  ax.set_ylabel('Y')
  ax.set_zlabel('Himmelblau(X, Y)')
  ax.contourf(x1, x2, Himmelblau.function(X1, X2))
  print("solution 2")
plotter(45, 45)


iplot = interactive(plotter, E = (-90, 90, 5),
                             A = (-90, 90, 5))
iplot
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-470-4aae975309c6> in <module>
#      18   ax.contourf(x1, x2, Himmelblau.function(X))
#      19   print("solution 2")
# ---> 20 plotter(45, 45)
#      21 from ipywidgets import interactive
#      22 iplot = interactive(plotter, E = (-90, 90, 5),
#
# <ipython-input-470-4aae975309c6> in plotter(E, A)
#      10   fig = plt.figure(figsize = [12, 8])
#      11   ax = plt.axes(projection='3d')
# ---> 12   ax.plot_surface(X1, X2, Himmelblau.function(X), cmap='jet', alpha=0.8)
#      13   ax.plot_wireframe(X1, X2, Himmelblau.function(X), rcount=15, ccount=15)
#      14   ax.view_init(elev=E, azim=A)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\_api\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     429                          else deprecation_addendum,
#     430                 **kwargs)
# --> 431         return func(*inner_args, **inner_kwargs)
#     432
#     433     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\mpl_toolkits\mplot3d\axes3d.py in plot_surface(self, X, Y, Z, norm, vmin, vmax, lightsource, *args, **kwargs)
#    1656
#    1657         if Z.ndim != 2:
# -> 1658             raise ValueError("Argument Z must be 2-dimensional.")
#    1659         if np.any(np.isnan(Z)):
#    1660             _api.warn_external(
#
# ValueError: Argument Z must be 2-dimensional.

# %% [markdown]
# [**Go Up**](#g66)

# %% [markdown]
# (っ^‿^)っ(っ^‿^)っ(っ^‿^)っ
